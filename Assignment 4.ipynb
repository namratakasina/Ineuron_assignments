# %%
#1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below 
#formula.
#area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
#Function to take the length of the sides of triangle from user should be defined in the parent 
#class and function to calculate the area should be defined in subclass.

class Sides:
    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c
class Fun(Sides):
    def area(self):
        s = (self.a +self.b + self.c)/2
        return(s*(s-self.a)*(s-self.b)*(s-self.c)) ** 0.5
obj = Fun(2,4,5)
print("Area of Triangle: {}". format(obj.area()))
# Out:
# Area of Triangle: 3.799671038392666

# %%
#1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns 
#the list of words that are longer than n.
def filter_long_words(wordlist, length):
    return (word for word in wordlist if len(word) >= length)

def main():
    words = input("Enter words separated by spaces: ").split()
    length = int(input("Minimum length of words to keep: "))
    print("Words longer than {} are {}.".format(length,
          ', '.join(filter_long_words(words, length))))

main()
# Out:
# Enter words separated by spaces: britney bts arijit ineuron
# Minimum length of words to keep: 3
# Words longer than 3 are britney, bts, arijit, ineuron.

# %%
#2.1 Write a Python program using function concept that maps list of words into a list of integers 
#representing the lengths of the corresponding words.
#Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
#Here 2,3 and 4 are the lengths of the words in the list.
listOfWords = input('List of Word: ').split() 
listOfInts = []
 
for i in range(len(listOfWords)):
    listOfInts.append(len(listOfWords[i]))
     
print ("List of wordlength:"+str(listOfInts))
# Out:
# List of Word: ineuron bike music dancing
# List of wordlength:[7, 4, 5, 7]

# %%
#2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if 
#it is a vowel, False otherwise.
def vowel(x):
    if x == "a"or x =="e" or x=="i" or x == "o" or x=="u":
        return "True"
    else:
        return "False "
a = input ("Enter the letter :- ")
print (vowel(a))
# Out:
# Enter the letter :- b
# False
